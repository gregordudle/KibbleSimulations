# %% [markdown]
# # Sequence of Open Modelica Simulations controlled by Python
# ### 1. Overview
# This script allows
# - to load a load a Kibble balance configuration (type of phase, coil, magnetic_field, motion_driver)
# - to load the adjustable parameters of the experiment (amplitude, period, offset)
# - to load the simulation parameters (stopTime, numberOfIntervals)
# - to run a simulation for given conditions
# - to store the results of the simulation together with the relevant simulation metadata in a JSON file
# - to store the data in a MongoDB
#
#
# Dugr, 2026-09-10

# %% [markdown]
# #### Structure of the JSON file containing simulation results and metadata
# ```
# {
#     metadata:{
#         para1: 13,
#         para2: 'hallo',
#         para3: 20
#     }
#     data:{
#         [
#             {
#                 'time':0,
#                 'coil1.p.v:0
#             },
#             {
#                 'time:0.01,
#                 'coil1.p.v:0
#             }
#         ]
#     }
# }
# ```

# %% [markdown]
# #### Comments on the code
# **File littering**
# OpenModelica creates a large amount of files when it compiles a model. These files are stored in the working directory of OpenModelica and remain there after completion of the simulation when OM is called from OMPython. To avoid *littering* in the directory, the code relies on a temporary directory (Simulation_Bin) where all temporary files are stored. At the end of the simulation, the file containing the results is copied from the *working_directory* to the *result_directory*.
#
# **Output format**
# Per default, OM stores the results in a matlab format file. This code specifies the outputFormat as .csv.

# %%
from OMPython import OMCSessionZMQ
import pandas as pd
import matplotlib.pyplot as plt 
import json
import os
from pathlib import Path
import shutil
from datetime import datetime, timezone
from pymongo import MongoClient

# %%
def list_to_dict(liste):
    """utility function to transform simulation option list to dict"""
    
    result = {}

    for item in liste:
        key, value = item.split("=", 1)
        key = key.strip()
        value = value.strip()

        # Remove surrounding quotes if present
        if (value.startswith("'") and value.endswith("'")) or \
        (value.startswith('"') and value.endswith('"')):
            value = value[1:-1]

        # Try converting to int or float
        else:
            try:
                value = int(value)
            except ValueError:
                try:
                    value = float(value)
                except ValueError:
                    pass

        result[key] = value
    return result


def load_and_run_dynamic(configuration):
    
    amplitude = configuration["motion"]["amplitude"]
    offset = configuration["motion"]["offset"]
    period = configuration["motion"]["period"]
    stopT = configuration["simulation"]["stopTime"]
    nbrInterv = configuration["simulation"]["numberOfIntervals"]
    print(f"Period: {period}")
    print(f"Amplitude: {amplitude}")
    print(f"Offset: {offset}")
    print()
    print(f"numberOfIntervals:{nbrInterv}")
    print(f"stopTime: {stopT}")
        
    zeitstamp = datetime.now(timezone.utc)                              # get the system time (in UTC)
    timestamp = zeitstamp.strftime("%Y%m%d%H%M%SZ") 

    # define the working directory
    temp_working_dir = "C:/Users/gregor.dudle/AppData/Local/Temp/Simulation_Bin/"   # temporary directory where OpenModelica can store the temporary files

    # base path of the Modelica Work
    base_dir = "C:/Users/gregor.dudle/OneDrive - OST/aFE/2026_Kibble/"
    results_dir = base_dir + "Results/"
    print(f"results_dir: {results_dir}")

    #################################################################################################
    ### define the components to be loaded                                                          
    ##

    # Kibble Balance Dynamic Phase
    kibble_balance_dir = base_dir+"Modelica_Work/DynamicPhase/"
    kibble_balance_model = configuration["main"]

    # Coil
    components_dir = base_dir + "Modelica_Work/Components/BIPM_Coil/"
    coil_model = configuration["coil"]

    # Magnetic field
    magnetic_dir = base_dir + "Modelica_Work/Components/BIPM_MagneticField/"
    magnetic_field = configuration["magnetic_field"]
    magnetic_field_filename = magnetic_dir + magnetic_field + ".csv"
    print(f"magnetic_field_filename: {magnetic_field_filename}")

    # Motion driver
    driver_dir = base_dir + "Modelica_Work/Components/Motion_driver/"
    x_driver_model = configuration["motion"]["driver"]


    # create the list of files to be loaded
    load_file_list = [
        kibble_balance_dir + kibble_balance_model + ".mo",
        components_dir + coil_model + ".mo",
        driver_dir + x_driver_model + ".mo"
    ]

    ##
    ### end of definition of the components
    ##################################################################################################


    #################################################################################################
  
    # define the result filenames
    #   the OMPython will first write all outputs to workingDir+filename (=origin_file)
    #   and store the simulation result together with the provided metadata to results_dir + "Simulation_" + timestamp + "_res.json"
    #   if uncommented below the script will also copy the csv file to resultsDir
    origin_file = temp_working_dir + kibble_balance_model + "_res.csv"
    results_file_csv = results_dir + "Simulation_" + timestamp + "_res.csv"
    results_file_json = results_dir + "Simulation_" +timestamp + "_res.json"

    # create temp_working_dir 
    try:
        os.mkdir(temp_working_dir)
    except FileExistsError:
        print("Temporary directory already exists.")
        
    print(f"Simulation data and metadata will be stored in 'Simulation_{timestamp}_res.json'")

    # load model and simulate in Open Modelica
    
    dynamic_phase_model = OMCSessionZMQ()
    
    dynamic_phase_model.sendExpression('loadModel(Modelica)')
    dynamic_phase_model.sendExpression("cd(\""+temp_working_dir+"\")")

    for filename in load_file_list:
        dynamic_phase_model.sendExpression(f"loadFile(\"{filename}\")")
    # the syntax is very subtle! do not remove quote or double back slashes as they are all required

    dynamic_phase_model.sendExpression(f'translateModel({kibble_balance_model})')


    # The following lines are VERY complicated. Multiple quotes are required and in some cases quotes need to be escaped
    # The (parsed) command should be
    #    sendExpression('simulate(DynamicPhaseV03,stopTime=100.0),stopTime=100.0,numberOfIntervals=5000,
    #                    simflags="-override=peri=20,
    #                                       ampli=0.003,
    #                                       magTableFileName=\"C:/Users/gregor.dudle/OneDrive - OST/aFE/2026_Kibble/Modelica_Work/Components/BIPM_MagneticField/BIPM_magnetic_field_01.csv\" " '

    simflags = f'-override=peri={period},'\
            f'ampli={amplitude},'\
            f'magTableFileName=\\"{magnetic_field_filename}\\"'

    sim = dynamic_phase_model.sendExpression(
        f'simulate({kibble_balance_model},'
        f'stopTime={stopT},'
        f'numberOfIntervals={nbrInterv},'
        f'simflags="{simflags}",'
        f'outputFormat="csv")'
    )


    #shutil.copy(origin_file,results_file_csv) # uncomment if the .csv is needed
    # collect metadata of the simulation and store them together with the simulation data in the file 'Simulation_xxxxxxxxxxx_res.json'
    metadata = {
        'id': timestamp,
        'date': datetime.today().strftime('%Y-%m-%d %H:%M:%S'),
        'user': os.getlogin(),
        'KibbleBalanceModel': kibble_balance_model,
        'CoilModel': coil_model,
        'MagneticField': magnetic_field,
        'Motion':{
            'Driver': x_driver_model,
            'Amplitude':amplitude,
            'Period':period,
            'Offset':offset,
        },
        
        'Simulation':  list_to_dict(str(sim["simulationOptions"]).split(", "))
        }

    df = pd.read_csv(origin_file)

    package ={
        'metadata':metadata,
        'data':df.to_dict(orient="records")
    }
    with open(results_file_json, "w", newline="") as f:
        w = f.write(json.dumps(package,indent=4))

    # add simulation to DB
    client = MongoClient("mongodb://localhost:27017/")
    DB = client["Simu_Data_Test"]
    collection = DB["Simu_Data"]
    collection.insert_one(metadata)

# %% [markdown]
# ### Structure for sequential machine
# The *configuration_file* contains all possible configurations of the apparatus.
# The *experiment-file* contains the sequence in which the different configurations are executed

# %%
configurations_file = "C:/Users/gregor.dudle/OneDrive - OST/aFE/2026_Kibble/Python_Scripts/Configurations/configurations.json"
config_df = pd.DataFrame()    
config_df = pd.read_json(configurations_file)

experiment_file = "C:/Users/gregor.dudle/OneDrive - OST/aFE/2026_Kibble/Python_Scripts/experiment_001.json"
experiment_series = pd.Series()
experiment_series = pd.read_json(experiment_file, typ='series')
step_counter = 1
for experiment in experiment_series:
    title = f"Step Nr. {step_counter}"
    print(title)
    print("===========")
    
    if config_df[experiment]["phase"]=="dynamic":
        load_and_run_dynamic(config_df[experiment])
    else:
        print("nicht dynamische Phase")
    
    step_counter += 1
    print("==========================================")
    print()
# Out:
# Step Nr. 1
# ===========
# Period: 20
# Amplitude: 0.004
# Offset: 0
#
# numberOfIntervals:5000
# stopTime: 100
# results_dir: C:/Users/gregor.dudle/OneDrive - OST/aFE/2026_Kibble/Results/
# magnetic_field_filename: C:/Users/gregor.dudle/OneDrive - OST/aFE/2026_Kibble/Modelica_Work/Components/BIPM_MagneticField/BIPM_magnetic_field_02.csv
# Temporary directory already exists.
# Simulation data and metadata will be stored in 'Simulation_20260922074125Z_res.json'
# C:\Users\gregor.dudle\AppData\Local\Temp\ipykernel_22864\324670347.py:110: DeprecationWarning: The class OMCSessionZMQ is depreciated and will be removed in future versions! Please use OMCSession* classes instead!
#   dynamic_phase_model = OMCSessionZMQ()
# ==========================================
#
# Step Nr. 2
# ===========
# nicht dynamische Phase
# ==========================================
#
# Step Nr. 3
# ===========
# Period: 25
# Amplitude: 0.004
# Offset: 0
#
# numberOfIntervals:1000
# stopTime: 100
# results_dir: C:/Users/gregor.dudle/OneDrive - OST/aFE/2026_Kibble/Results/
# magnetic_field_filename: C:/Users/gregor.dudle/OneDrive - OST/aFE/2026_Kibble/Modelica_Work/Components/BIPM_MagneticField/BIPM_magnetic_field_01.csv
# Temporary directory already exists.
# Simulation data and metadata will be stored in 'Simulation_20260922074138Z_res.json'
# C:\Users\gregor.dudle\AppData\Local\Temp\ipykernel_22864\324670347.py:110: DeprecationWarning: The class OMCSessionZMQ is depreciated and will be removed in future versions! Please use OMCSession* classes instead!
#   dynamic_phase_model = OMCSessionZMQ()
# ==========================================
